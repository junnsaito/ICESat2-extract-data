# %% [markdown]
# Extract Icesat2 data (This code is validate only after downloading HDF5 file)

# %%
from pathlib import Path

# Our data folder 
data_home = Path('/home/junsaito/Icesat2_with_DEM/Data')

# Create folder if it doesn't exist
data_home.mkdir(exist_ok=True)

# %%
from icepyx import icesat2data as ipd

short_name = 'ATL06'
spatial_extent = [-138.67,58.32,-135.99, 59.84]  # PIG
date_range = ['2018-10-14','2020-06-16']

# spatial_extent = [148, -81, 162, -80]  # Byrd
# date_range = ['2018-10-14','2018-12-22']

region = ipd.Icesat2Data(short_name, spatial_extent, date_range)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e20eed65d7e7> in <module>
# ----> 1 from icepyx import icesat2data as ipd
#       2
#       3 short_name = 'ATL06'
#       4 spatial_extent = [-138.67,58.32,-135.99, 59.84]  # PIG
#       5 date_range = ['2018-10-14','2020-06-16']
#
# ModuleNotFoundError: No module named 'icepyx'

# %%
# %matplotlib widget
print('product:    ', region.dataset)
print('dates:      ', region.dates)
print('start time: ', region.start_time)
print('end time:   ', region.end_time)
print('version:    ', region.dataset_version)
print('extent:     ', region.spatial_extent)

print('\nDATA:')
print('\n'.join([str(item) for item in region.avail_granules().items()]))

region.visualize_spatial_extent()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-113-c4836514003b> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 print('product:    ', region.dataset)
#       3 print('dates:      ', region.dates)
#       4 print('start time: ', region.start_time)
#       5 print('end time:   ', region.end_time)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# </home/junsaito/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3417                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3418
# -> 3419         pt.activate_matplotlib(backend)
#    3420         pt.configure_inline_support(self, backend)
#    3421
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     320     from matplotlib import pyplot as plt
#     321
# --> 322     plt.switch_backend(backend)
#     323
#     324     plt.show._needmain = False
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     219         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     220
# --> 221     backend_mod = importlib.import_module(backend_name)
#     222     Backend = type(
#     223         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# ~/anaconda3/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'ipympl'

# %% [markdown]
# You can dowload the data by useing the below code. I don't recommend it. It would be better to skip next code.

# %%
#name = '-----'
#email = '-----@gmail.com'

# Only download if data folder is empty
if not list(data_home.glob('*.h5')):
    region.earthdata_login(name, email)
    region.download_granules(data_home)

# %% [markdown]
# Run it from here again

# %%
files = list(data_home.glob('*.h5'))

for f in files[:10]: print(f)
print('Total number of files:', len(files))
# Out:
# /home/junsaito/crossovers/contributors/jun/ATL06_20191119173713_08220505_003_01.h5
# /home/junsaito/crossovers/contributors/jun/ATL06_20190814163946_07270405_003_01.h5
# Total number of files: 2

# %%
# !h5ls -r {files[0]}
# Out:
# /                        Group
# /METADATA                Group
# /METADATA/AcquisitionInformation Group
# /METADATA/AcquisitionInformation/lidar Group
# /METADATA/AcquisitionInformation/lidarDocument Group
# /METADATA/AcquisitionInformation/platform Group
# /METADATA/AcquisitionInformation/platformDocument Group
# /METADATA/DataQuality    Group
# /METADATA/DataQuality/CompletenessOmission Group
# /METADATA/DataQuality/DomainConsistency Group
# /METADATA/DatasetIdentification Group
# /METADATA/Extent         Group
# /METADATA/Lineage        Group
# /METADATA/Lineage/ANC06-01 Group
# /METADATA/Lineage/ANC06-02 Group
# /METADATA/Lineage/ANC06-03 Group
# /METADATA/Lineage/ANC17  Group
# /METADATA/Lineage/ANC19  Group
# /METADATA/Lineage/ANC25-06 Group
# /METADATA/Lineage/ANC26-06 Group
# /METADATA/Lineage/ANC28  Group
# /METADATA/Lineage/ANC36-06 Group
# /METADATA/Lineage/ANC38-06 Group
# /METADATA/Lineage/ATL03  Group
# /METADATA/Lineage/ATL09  Group
# /METADATA/Lineage/Control Group
# /METADATA/ProcessStep    Group
# /METADATA/ProcessStep/Browse Group
# /METADATA/ProcessStep/Metadata Group
# /METADATA/ProcessStep/PGE Group
# /METADATA/ProcessStep/QA Group
# /METADATA/ProductSpecificationDocument Group
# /METADATA/QADatasetIdentification Group
# /METADATA/SeriesIdentification Group
# /ancillary_data          Group
# /ancillary_data/atlas_sdp_gps_epoch Dataset {1}
# /ancillary_data/control  Dataset {1}
# /ancillary_data/data_end_utc Dataset {1}
# /ancillary_data/data_start_utc Dataset {1}
# /ancillary_data/end_cycle Dataset {1}
# /ancillary_data/end_delta_time Dataset {1}
# /ancillary_data/end_geoseg Dataset {1}
# /ancillary_data/end_gpssow Dataset {1}
# /ancillary_data/end_gpsweek Dataset {1}
# /ancillary_data/end_orbit Dataset {1}
# /ancillary_data/end_region Dataset {1}
# /ancillary_data/end_rgt  Dataset {1}
# /ancillary_data/granule_end_utc Dataset {1}
# /ancillary_data/granule_start_utc Dataset {1}
# /ancillary_data/land_ice Group
# /ancillary_data/land_ice/dt_hist Dataset {1}
# /ancillary_data/land_ice/fit_maxiter Dataset {1}
# /ancillary_data/land_ice/fpb_maxiter Dataset {1}
# /ancillary_data/land_ice/max_res_ids Dataset {1}
# /ancillary_data/land_ice/maxiter Dataset {1}
# /ancillary_data/land_ice/min_dist Dataset {1}
# /ancillary_data/land_ice/min_gain_th Dataset {1}
# /ancillary_data/land_ice/min_n_pe Dataset {1}
# /ancillary_data/land_ice/min_n_sel Dataset {1}
# /ancillary_data/land_ice/min_signal_conf Dataset {1}
# /ancillary_data/land_ice/n_hist Dataset {1}
# /ancillary_data/land_ice/n_sigmas Dataset {1}
# /ancillary_data/land_ice/nhist_bins Dataset {1}
# /ancillary_data/land_ice/proc_interval Dataset {1}
# /ancillary_data/land_ice/qs_lim_bsc Dataset {1}
# /ancillary_data/land_ice/qs_lim_hrs Dataset {1}
# /ancillary_data/land_ice/qs_lim_hsigma Dataset {1}
# /ancillary_data/land_ice/qs_lim_msw Dataset {1}
# /ancillary_data/land_ice/qs_lim_snr Dataset {1}
# /ancillary_data/land_ice/qs_lim_sss Dataset {1}
# /ancillary_data/land_ice/rbin_width Dataset {1}
# /ancillary_data/land_ice/sigma_beam Dataset {1}
# /ancillary_data/land_ice/sigma_tx Dataset {1}
# /ancillary_data/land_ice/t_dead Dataset {1}
# /ancillary_data/qa_at_interval Dataset {1}
# /ancillary_data/release  Dataset {1}
# /ancillary_data/start_cycle Dataset {1}
# /ancillary_data/start_delta_time Dataset {1}
# /ancillary_data/start_geoseg Dataset {1}
# /ancillary_data/start_gpssow Dataset {1}
# /ancillary_data/start_gpsweek Dataset {1}
# /ancillary_data/start_orbit Dataset {1}
# /ancillary_data/start_region Dataset {1}
# /ancillary_data/start_rgt Dataset {1}
# /ancillary_data/version  Dataset {1}
# /gt1l                    Group
# /gt1l/land_ice_segments  Group
# /gt1l/land_ice_segments/atl06_quality_summary Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction Group
# /gt1l/land_ice_segments/bias_correction/fpb_mean_corr Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_med_corr Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/fpb_n_corr Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/med_r_fit Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/tx_mean_corr Dataset {23514/Inf}
# /gt1l/land_ice_segments/bias_correction/tx_med_corr Dataset {23514/Inf}
# /gt1l/land_ice_segments/delta_time Dataset {23514/Inf}
# /gt1l/land_ice_segments/dem Group
# /gt1l/land_ice_segments/dem/dem_flag Dataset {23514/Inf}
# /gt1l/land_ice_segments/dem/dem_h Dataset {23514/Inf}
# /gt1l/land_ice_segments/dem/geoid_h Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics Group
# /gt1l/land_ice_segments/fit_statistics/dh_fit_dx Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/dh_fit_dy Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_expected_rms Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_mean Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_rms_misfit Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/h_robust_sprd Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/n_fit_photons Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/n_seg_pulses Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/sigma_h_mean Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/signal_selection_source Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/snr Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/snr_significance Dataset {23514/Inf}
# /gt1l/land_ice_segments/fit_statistics/w_surface_window_final Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical Group
# /gt1l/land_ice_segments/geophysical/bckgrd Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/bsnow_conf Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/bsnow_h Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/bsnow_od Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/cloud_flg_asr Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/cloud_flg_atm Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/dac Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/e_bckgrd Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/layer_flag Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/msw_flag Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/neutat_delay_total Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/r_eff Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/solar_azimuth Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/solar_elevation Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/tide_earth Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/tide_equilibrium Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/tide_load Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/tide_ocean Dataset {23514/Inf}
# /gt1l/land_ice_segments/geophysical/tide_pole Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track Group
# /gt1l/land_ice_segments/ground_track/ref_azimuth Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/ref_coelv Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/seg_azimuth Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/sigma_geo_at Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/sigma_geo_r Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/sigma_geo_xt Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/x_atc Dataset {23514/Inf}
# /gt1l/land_ice_segments/ground_track/y_atc Dataset {23514/Inf}
# /gt1l/land_ice_segments/h_li Dataset {23514/Inf}
# /gt1l/land_ice_segments/h_li_sigma Dataset {23514/Inf}
# /gt1l/land_ice_segments/latitude Dataset {23514/Inf}
# /gt1l/land_ice_segments/longitude Dataset {23514/Inf}
# /gt1l/land_ice_segments/segment_id Dataset {23514/Inf}
# /gt1l/land_ice_segments/sigma_geo_h Dataset {23514/Inf}
# /gt1l/residual_histogram Group
# /gt1l/residual_histogram/bckgrd_per_m Dataset {2103/Inf}
# /gt1l/residual_histogram/bin_top_h Dataset {748}
# /gt1l/residual_histogram/count Dataset {2103/Inf, 748}
# /gt1l/residual_histogram/delta_time Dataset {2103/Inf}
# /gt1l/residual_histogram/ds_segment_id Dataset {10}
# /gt1l/residual_histogram/lat_mean Dataset {2103/Inf}
# /gt1l/residual_histogram/lon_mean Dataset {2103/Inf}
# /gt1l/residual_histogram/pulse_count Dataset {2103/Inf}
# /gt1l/residual_histogram/segment_id_list Dataset {2103/Inf, 10}
# /gt1l/residual_histogram/x_atc_mean Dataset {2103/Inf}
# /gt1l/segment_quality    Group
# /gt1l/segment_quality/delta_time Dataset {23514/Inf}
# /gt1l/segment_quality/record_number Dataset {23514/Inf}
# /gt1l/segment_quality/reference_pt_lat Dataset {23514/Inf}
# /gt1l/segment_quality/reference_pt_lon Dataset {23514/Inf}
# /gt1l/segment_quality/segment_id Dataset {23514/Inf}
# /gt1l/segment_quality/signal_selection_source Dataset {23514/Inf}
# /gt1l/segment_quality/signal_selection_status Group
# /gt1l/segment_quality/signal_selection_status/signal_selection_status_all Dataset {23514/Inf}
# /gt1l/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {23514/Inf}
# /gt1l/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {23514/Inf}
# /gt1r                    Group
# /gt1r/land_ice_segments  Group
# /gt1r/land_ice_segments/atl06_quality_summary Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction Group
# /gt1r/land_ice_segments/bias_correction/fpb_mean_corr Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_med_corr Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/fpb_n_corr Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/med_r_fit Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/tx_mean_corr Dataset {23514/Inf}
# /gt1r/land_ice_segments/bias_correction/tx_med_corr Dataset {23514/Inf}
# /gt1r/land_ice_segments/delta_time Dataset {23514/Inf}
# /gt1r/land_ice_segments/dem Group
# /gt1r/land_ice_segments/dem/dem_flag Dataset {23514/Inf}
# /gt1r/land_ice_segments/dem/dem_h Dataset {23514/Inf}
# /gt1r/land_ice_segments/dem/geoid_h Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics Group
# /gt1r/land_ice_segments/fit_statistics/dh_fit_dx Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/dh_fit_dy Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_expected_rms Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_mean Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_rms_misfit Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/h_robust_sprd Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/n_fit_photons Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/n_seg_pulses Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/sigma_h_mean Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/signal_selection_source Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/snr Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/snr_significance Dataset {23514/Inf}
# /gt1r/land_ice_segments/fit_statistics/w_surface_window_final Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical Group
# /gt1r/land_ice_segments/geophysical/bckgrd Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/bsnow_conf Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/bsnow_h Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/bsnow_od Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/cloud_flg_asr Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/cloud_flg_atm Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/dac Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/e_bckgrd Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/layer_flag Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/msw_flag Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/neutat_delay_total Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/r_eff Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/solar_azimuth Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/solar_elevation Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/tide_earth Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/tide_equilibrium Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/tide_load Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/tide_ocean Dataset {23514/Inf}
# /gt1r/land_ice_segments/geophysical/tide_pole Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track Group
# /gt1r/land_ice_segments/ground_track/ref_azimuth Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/ref_coelv Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/seg_azimuth Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/sigma_geo_at Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/sigma_geo_r Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/sigma_geo_xt Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/x_atc Dataset {23514/Inf}
# /gt1r/land_ice_segments/ground_track/y_atc Dataset {23514/Inf}
# /gt1r/land_ice_segments/h_li Dataset {23514/Inf}
# /gt1r/land_ice_segments/h_li_sigma Dataset {23514/Inf}
# /gt1r/land_ice_segments/latitude Dataset {23514/Inf}
# /gt1r/land_ice_segments/longitude Dataset {23514/Inf}
# /gt1r/land_ice_segments/segment_id Dataset {23514/Inf}
# /gt1r/land_ice_segments/sigma_geo_h Dataset {23514/Inf}
# /gt1r/residual_histogram Group
# /gt1r/residual_histogram/bckgrd_per_m Dataset {2103/Inf}
# /gt1r/residual_histogram/bin_top_h Dataset {748}
# /gt1r/residual_histogram/count Dataset {2103/Inf, 748}
# /gt1r/residual_histogram/delta_time Dataset {2103/Inf}
# /gt1r/residual_histogram/ds_segment_id Dataset {10}
# /gt1r/residual_histogram/lat_mean Dataset {2103/Inf}
# /gt1r/residual_histogram/lon_mean Dataset {2103/Inf}
# /gt1r/residual_histogram/pulse_count Dataset {2103/Inf}
# /gt1r/residual_histogram/segment_id_list Dataset {2103/Inf, 10}
# /gt1r/residual_histogram/x_atc_mean Dataset {2103/Inf}
# /gt1r/segment_quality    Group
# /gt1r/segment_quality/delta_time Dataset {23514/Inf}
# /gt1r/segment_quality/record_number Dataset {23514/Inf}
# /gt1r/segment_quality/reference_pt_lat Dataset {23514/Inf}
# /gt1r/segment_quality/reference_pt_lon Dataset {23514/Inf}
# /gt1r/segment_quality/segment_id Dataset {23514/Inf}
# /gt1r/segment_quality/signal_selection_source Dataset {23514/Inf}
# /gt1r/segment_quality/signal_selection_status Group
# /gt1r/segment_quality/signal_selection_status/signal_selection_status_all Dataset {23514/Inf}
# /gt1r/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {23514/Inf}
# /gt1r/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {23514/Inf}
# /gt2l                    Group
# /gt2l/land_ice_segments  Group
# /gt2l/land_ice_segments/atl06_quality_summary Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction Group
# /gt2l/land_ice_segments/bias_correction/fpb_mean_corr Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_med_corr Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/fpb_n_corr Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/med_r_fit Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/tx_mean_corr Dataset {22544/Inf}
# /gt2l/land_ice_segments/bias_correction/tx_med_corr Dataset {22544/Inf}
# /gt2l/land_ice_segments/delta_time Dataset {22544/Inf}
# /gt2l/land_ice_segments/dem Group
# /gt2l/land_ice_segments/dem/dem_flag Dataset {22544/Inf}
# /gt2l/land_ice_segments/dem/dem_h Dataset {22544/Inf}
# /gt2l/land_ice_segments/dem/geoid_h Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics Group
# /gt2l/land_ice_segments/fit_statistics/dh_fit_dx Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/dh_fit_dy Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_expected_rms Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_mean Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_rms_misfit Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/h_robust_sprd Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/n_fit_photons Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/n_seg_pulses Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/sigma_h_mean Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/signal_selection_source Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/snr Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/snr_significance Dataset {22544/Inf}
# /gt2l/land_ice_segments/fit_statistics/w_surface_window_final Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical Group
# /gt2l/land_ice_segments/geophysical/bckgrd Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/bsnow_conf Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/bsnow_h Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/bsnow_od Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/cloud_flg_asr Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/cloud_flg_atm Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/dac Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/e_bckgrd Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/layer_flag Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/msw_flag Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/neutat_delay_total Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/r_eff Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/solar_azimuth Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/solar_elevation Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/tide_earth Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/tide_equilibrium Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/tide_load Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/tide_ocean Dataset {22544/Inf}
# /gt2l/land_ice_segments/geophysical/tide_pole Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track Group
# /gt2l/land_ice_segments/ground_track/ref_azimuth Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/ref_coelv Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/seg_azimuth Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/sigma_geo_at Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/sigma_geo_r Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/sigma_geo_xt Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/x_atc Dataset {22544/Inf}
# /gt2l/land_ice_segments/ground_track/y_atc Dataset {22544/Inf}
# /gt2l/land_ice_segments/h_li Dataset {22544/Inf}
# /gt2l/land_ice_segments/h_li_sigma Dataset {22544/Inf}
# /gt2l/land_ice_segments/latitude Dataset {22544/Inf}
# /gt2l/land_ice_segments/longitude Dataset {22544/Inf}
# /gt2l/land_ice_segments/segment_id Dataset {22544/Inf}
# /gt2l/land_ice_segments/sigma_geo_h Dataset {22544/Inf}
# /gt2l/residual_histogram Group
# /gt2l/residual_histogram/bckgrd_per_m Dataset {2031/Inf}
# /gt2l/residual_histogram/bin_top_h Dataset {748}
# /gt2l/residual_histogram/count Dataset {2031/Inf, 748}
# /gt2l/residual_histogram/delta_time Dataset {2031/Inf}
# /gt2l/residual_histogram/ds_segment_id Dataset {10}
# /gt2l/residual_histogram/lat_mean Dataset {2031/Inf}
# /gt2l/residual_histogram/lon_mean Dataset {2031/Inf}
# /gt2l/residual_histogram/pulse_count Dataset {2031/Inf}
# /gt2l/residual_histogram/segment_id_list Dataset {2031/Inf, 10}
# /gt2l/residual_histogram/x_atc_mean Dataset {2031/Inf}
# /gt2l/segment_quality    Group
# /gt2l/segment_quality/delta_time Dataset {22544/Inf}
# /gt2l/segment_quality/record_number Dataset {22544/Inf}
# /gt2l/segment_quality/reference_pt_lat Dataset {22544/Inf}
# /gt2l/segment_quality/reference_pt_lon Dataset {22544/Inf}
# /gt2l/segment_quality/segment_id Dataset {22544/Inf}
# /gt2l/segment_quality/signal_selection_source Dataset {22544/Inf}
# /gt2l/segment_quality/signal_selection_status Group
# /gt2l/segment_quality/signal_selection_status/signal_selection_status_all Dataset {22544/Inf}
# /gt2l/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {22544/Inf}
# /gt2l/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {22544/Inf}
# /gt2r                    Group
# /gt2r/land_ice_segments  Group
# /gt2r/land_ice_segments/atl06_quality_summary Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction Group
# /gt2r/land_ice_segments/bias_correction/fpb_mean_corr Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_med_corr Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/fpb_n_corr Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/med_r_fit Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/tx_mean_corr Dataset {22544/Inf}
# /gt2r/land_ice_segments/bias_correction/tx_med_corr Dataset {22544/Inf}
# /gt2r/land_ice_segments/delta_time Dataset {22544/Inf}
# /gt2r/land_ice_segments/dem Group
# /gt2r/land_ice_segments/dem/dem_flag Dataset {22544/Inf}
# /gt2r/land_ice_segments/dem/dem_h Dataset {22544/Inf}
# /gt2r/land_ice_segments/dem/geoid_h Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics Group
# /gt2r/land_ice_segments/fit_statistics/dh_fit_dx Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/dh_fit_dy Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_expected_rms Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_mean Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_rms_misfit Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/h_robust_sprd Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/n_fit_photons Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/n_seg_pulses Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/sigma_h_mean Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/signal_selection_source Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/snr Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/snr_significance Dataset {22544/Inf}
# /gt2r/land_ice_segments/fit_statistics/w_surface_window_final Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical Group
# /gt2r/land_ice_segments/geophysical/bckgrd Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/bsnow_conf Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/bsnow_h Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/bsnow_od Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/cloud_flg_asr Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/cloud_flg_atm Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/dac Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/e_bckgrd Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/layer_flag Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/msw_flag Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/neutat_delay_total Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/r_eff Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/solar_azimuth Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/solar_elevation Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/tide_earth Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/tide_equilibrium Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/tide_load Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/tide_ocean Dataset {22544/Inf}
# /gt2r/land_ice_segments/geophysical/tide_pole Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track Group
# /gt2r/land_ice_segments/ground_track/ref_azimuth Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/ref_coelv Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/seg_azimuth Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/sigma_geo_at Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/sigma_geo_r Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/sigma_geo_xt Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/x_atc Dataset {22544/Inf}
# /gt2r/land_ice_segments/ground_track/y_atc Dataset {22544/Inf}
# /gt2r/land_ice_segments/h_li Dataset {22544/Inf}
# /gt2r/land_ice_segments/h_li_sigma Dataset {22544/Inf}
# /gt2r/land_ice_segments/latitude Dataset {22544/Inf}
# /gt2r/land_ice_segments/longitude Dataset {22544/Inf}
# /gt2r/land_ice_segments/segment_id Dataset {22544/Inf}
# /gt2r/land_ice_segments/sigma_geo_h Dataset {22544/Inf}
# /gt2r/residual_histogram Group
# /gt2r/residual_histogram/bckgrd_per_m Dataset {2031/Inf}
# /gt2r/residual_histogram/bin_top_h Dataset {748}
# /gt2r/residual_histogram/count Dataset {2031/Inf, 748}
# /gt2r/residual_histogram/delta_time Dataset {2031/Inf}
# /gt2r/residual_histogram/ds_segment_id Dataset {10}
# /gt2r/residual_histogram/lat_mean Dataset {2031/Inf}
# /gt2r/residual_histogram/lon_mean Dataset {2031/Inf}
# /gt2r/residual_histogram/pulse_count Dataset {2031/Inf}
# /gt2r/residual_histogram/segment_id_list Dataset {2031/Inf, 10}
# /gt2r/residual_histogram/x_atc_mean Dataset {2031/Inf}
# /gt2r/segment_quality    Group
# /gt2r/segment_quality/delta_time Dataset {22544/Inf}
# /gt2r/segment_quality/record_number Dataset {22544/Inf}
# /gt2r/segment_quality/reference_pt_lat Dataset {22544/Inf}
# /gt2r/segment_quality/reference_pt_lon Dataset {22544/Inf}
# /gt2r/segment_quality/segment_id Dataset {22544/Inf}
# /gt2r/segment_quality/signal_selection_source Dataset {22544/Inf}
# /gt2r/segment_quality/signal_selection_status Group
# /gt2r/segment_quality/signal_selection_status/signal_selection_status_all Dataset {22544/Inf}
# /gt2r/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {22544/Inf}
# /gt2r/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {22544/Inf}
# /gt3l                    Group
# /gt3l/land_ice_segments  Group
# /gt3l/land_ice_segments/atl06_quality_summary Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction Group
# /gt3l/land_ice_segments/bias_correction/fpb_mean_corr Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_med_corr Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/fpb_n_corr Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/med_r_fit Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/tx_mean_corr Dataset {23489/Inf}
# /gt3l/land_ice_segments/bias_correction/tx_med_corr Dataset {23489/Inf}
# /gt3l/land_ice_segments/delta_time Dataset {23489/Inf}
# /gt3l/land_ice_segments/dem Group
# /gt3l/land_ice_segments/dem/dem_flag Dataset {23489/Inf}
# /gt3l/land_ice_segments/dem/dem_h Dataset {23489/Inf}
# /gt3l/land_ice_segments/dem/geoid_h Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics Group
# /gt3l/land_ice_segments/fit_statistics/dh_fit_dx Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/dh_fit_dy Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_expected_rms Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_mean Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_rms_misfit Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/h_robust_sprd Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/n_fit_photons Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/n_seg_pulses Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/sigma_h_mean Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/signal_selection_source Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/snr Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/snr_significance Dataset {23489/Inf}
# /gt3l/land_ice_segments/fit_statistics/w_surface_window_final Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical Group
# /gt3l/land_ice_segments/geophysical/bckgrd Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/bsnow_conf Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/bsnow_h Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/bsnow_od Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/cloud_flg_asr Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/cloud_flg_atm Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/dac Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/e_bckgrd Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/layer_flag Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/msw_flag Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/neutat_delay_total Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/r_eff Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/solar_azimuth Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/solar_elevation Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/tide_earth Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/tide_equilibrium Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/tide_load Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/tide_ocean Dataset {23489/Inf}
# /gt3l/land_ice_segments/geophysical/tide_pole Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track Group
# /gt3l/land_ice_segments/ground_track/ref_azimuth Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/ref_coelv Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/seg_azimuth Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/sigma_geo_at Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/sigma_geo_r Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/sigma_geo_xt Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/x_atc Dataset {23489/Inf}
# /gt3l/land_ice_segments/ground_track/y_atc Dataset {23489/Inf}
# /gt3l/land_ice_segments/h_li Dataset {23489/Inf}
# /gt3l/land_ice_segments/h_li_sigma Dataset {23489/Inf}
# /gt3l/land_ice_segments/latitude Dataset {23489/Inf}
# /gt3l/land_ice_segments/longitude Dataset {23489/Inf}
# /gt3l/land_ice_segments/segment_id Dataset {23489/Inf}
# /gt3l/land_ice_segments/sigma_geo_h Dataset {23489/Inf}
# /gt3l/residual_histogram Group
# /gt3l/residual_histogram/bckgrd_per_m Dataset {2133/Inf}
# /gt3l/residual_histogram/bin_top_h Dataset {748}
# /gt3l/residual_histogram/count Dataset {2133/Inf, 748}
# /gt3l/residual_histogram/delta_time Dataset {2133/Inf}
# /gt3l/residual_histogram/ds_segment_id Dataset {10}
# /gt3l/residual_histogram/lat_mean Dataset {2133/Inf}
# /gt3l/residual_histogram/lon_mean Dataset {2133/Inf}
# /gt3l/residual_histogram/pulse_count Dataset {2133/Inf}
# /gt3l/residual_histogram/segment_id_list Dataset {2133/Inf, 10}
# /gt3l/residual_histogram/x_atc_mean Dataset {2133/Inf}
# /gt3l/segment_quality    Group
# /gt3l/segment_quality/delta_time Dataset {23489/Inf}
# /gt3l/segment_quality/record_number Dataset {23489/Inf}
# /gt3l/segment_quality/reference_pt_lat Dataset {23489/Inf}
# /gt3l/segment_quality/reference_pt_lon Dataset {23489/Inf}
# /gt3l/segment_quality/segment_id Dataset {23489/Inf}
# /gt3l/segment_quality/signal_selection_source Dataset {23489/Inf}
# /gt3l/segment_quality/signal_selection_status Group
# /gt3l/segment_quality/signal_selection_status/signal_selection_status_all Dataset {23489/Inf}
# /gt3l/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {23489/Inf}
# /gt3l/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {23489/Inf}
# /gt3r                    Group
# /gt3r/land_ice_segments  Group
# /gt3r/land_ice_segments/atl06_quality_summary Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction Group
# /gt3r/land_ice_segments/bias_correction/fpb_mean_corr Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_mean_corr_sigma Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_med_corr Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_med_corr_sigma Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/fpb_n_corr Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/med_r_fit Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/tx_mean_corr Dataset {23489/Inf}
# /gt3r/land_ice_segments/bias_correction/tx_med_corr Dataset {23489/Inf}
# /gt3r/land_ice_segments/delta_time Dataset {23489/Inf}
# /gt3r/land_ice_segments/dem Group
# /gt3r/land_ice_segments/dem/dem_flag Dataset {23489/Inf}
# /gt3r/land_ice_segments/dem/dem_h Dataset {23489/Inf}
# /gt3r/land_ice_segments/dem/geoid_h Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics Group
# /gt3r/land_ice_segments/fit_statistics/dh_fit_dx Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/dh_fit_dx_sigma Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/dh_fit_dy Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_expected_rms Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_mean Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_rms_misfit Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/h_robust_sprd Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/n_fit_photons Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/n_seg_pulses Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/sigma_h_mean Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/signal_selection_source Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/signal_selection_source_status Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/snr Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/snr_significance Dataset {23489/Inf}
# /gt3r/land_ice_segments/fit_statistics/w_surface_window_final Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical Group
# /gt3r/land_ice_segments/geophysical/bckgrd Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/bsnow_conf Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/bsnow_h Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/bsnow_od Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/cloud_flg_asr Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/cloud_flg_atm Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/dac Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/e_bckgrd Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/layer_flag Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/msw_flag Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/neutat_delay_total Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/r_eff Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/solar_azimuth Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/solar_elevation Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/tide_earth Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/tide_equilibrium Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/tide_load Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/tide_ocean Dataset {23489/Inf}
# /gt3r/land_ice_segments/geophysical/tide_pole Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track Group
# /gt3r/land_ice_segments/ground_track/ref_azimuth Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/ref_coelv Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/seg_azimuth Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/sigma_geo_at Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/sigma_geo_r Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/sigma_geo_xt Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/x_atc Dataset {23489/Inf}
# /gt3r/land_ice_segments/ground_track/y_atc Dataset {23489/Inf}
# /gt3r/land_ice_segments/h_li Dataset {23489/Inf}
# /gt3r/land_ice_segments/h_li_sigma Dataset {23489/Inf}
# /gt3r/land_ice_segments/latitude Dataset {23489/Inf}
# /gt3r/land_ice_segments/longitude Dataset {23489/Inf}
# /gt3r/land_ice_segments/segment_id Dataset {23489/Inf}
# /gt3r/land_ice_segments/sigma_geo_h Dataset {23489/Inf}
# /gt3r/residual_histogram Group
# /gt3r/residual_histogram/bckgrd_per_m Dataset {2133/Inf}
# /gt3r/residual_histogram/bin_top_h Dataset {748}
# /gt3r/residual_histogram/count Dataset {2133/Inf, 748}
# /gt3r/residual_histogram/delta_time Dataset {2133/Inf}
# /gt3r/residual_histogram/ds_segment_id Dataset {10}
# /gt3r/residual_histogram/lat_mean Dataset {2133/Inf}
# /gt3r/residual_histogram/lon_mean Dataset {2133/Inf}
# /gt3r/residual_histogram/pulse_count Dataset {2133/Inf}
# /gt3r/residual_histogram/segment_id_list Dataset {2133/Inf, 10}
# /gt3r/residual_histogram/x_atc_mean Dataset {2133/Inf}
# /gt3r/segment_quality    Group
# /gt3r/segment_quality/delta_time Dataset {23489/Inf}
# /gt3r/segment_quality/record_number Dataset {23489/Inf}
# /gt3r/segment_quality/reference_pt_lat Dataset {23489/Inf}
# /gt3r/segment_quality/reference_pt_lon Dataset {23489/Inf}
# /gt3r/segment_quality/segment_id Dataset {23489/Inf}
# /gt3r/segment_quality/signal_selection_source Dataset {23489/Inf}
# /gt3r/segment_quality/signal_selection_status Group
# /gt3r/segment_quality/signal_selection_status/signal_selection_status_all Dataset {23489/Inf}
# /gt3r/segment_quality/signal_selection_status/signal_selection_status_backup Dataset {23489/Inf}
# /gt3r/segment_quality/signal_selection_status/signal_selection_status_confident Dataset {23489/Inf}
# /orbit_info              Group
# /orbit_info/crossing_time Dataset {1/Inf}
# /orbit_info/cycle_number Dataset {1/Inf}
# /orbit_info/lan          Dataset {1/Inf}
# /orbit_info/orbit_number Dataset {1/Inf}
# /orbit_info/rgt          Dataset {1/Inf}
# /orbit_info/sc_orient    Dataset {1/Inf}
# /orbit_info/sc_orient_time Dataset {1/Inf}
# /quality_assessment      Group
# /quality_assessment/gt1l Group
# /quality_assessment/gt1l/delta_time Dataset {110/Inf}
# /quality_assessment/gt1l/lat_mean Dataset {110/Inf}
# /quality_assessment/gt1l/lon_mean Dataset {110/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_0 Dataset {110/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_1 Dataset {110/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_2 Dataset {110/Inf}
# /quality_assessment/gt1l/signal_selection_source_fraction_3 Dataset {110/Inf}
# /quality_assessment/gt1r Group
# /quality_assessment/gt1r/delta_time Dataset {110/Inf}
# /quality_assessment/gt1r/lat_mean Dataset {110/Inf}
# /quality_assessment/gt1r/lon_mean Dataset {110/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_0 Dataset {110/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_1 Dataset {110/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_2 Dataset {110/Inf}
# /quality_assessment/gt1r/signal_selection_source_fraction_3 Dataset {110/Inf}
# /quality_assessment/gt2l Group
# /quality_assessment/gt2l/delta_time Dataset {109/Inf}
# /quality_assessment/gt2l/lat_mean Dataset {109/Inf}
# /quality_assessment/gt2l/lon_mean Dataset {109/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_0 Dataset {109/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_1 Dataset {109/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_2 Dataset {109/Inf}
# /quality_assessment/gt2l/signal_selection_source_fraction_3 Dataset {109/Inf}
# /quality_assessment/gt2r Group
# /quality_assessment/gt2r/delta_time Dataset {109/Inf}
# /quality_assessment/gt2r/lat_mean Dataset {109/Inf}
# /quality_assessment/gt2r/lon_mean Dataset {109/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_0 Dataset {109/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_1 Dataset {109/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_2 Dataset {109/Inf}
# /quality_assessment/gt2r/signal_selection_source_fraction_3 Dataset {109/Inf}
# /quality_assessment/gt3l Group
# /quality_assessment/gt3l/delta_time Dataset {111/Inf}
# /quality_assessment/gt3l/lat_mean Dataset {111/Inf}
# /quality_assessment/gt3l/lon_mean Dataset {111/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_0 Dataset {111/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_1 Dataset {111/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_2 Dataset {111/Inf}
# /quality_assessment/gt3l/signal_selection_source_fraction_3 Dataset {111/Inf}
# /quality_assessment/gt3r Group
# /quality_assessment/gt3r/delta_time Dataset {111/Inf}
# /quality_assessment/gt3r/lat_mean Dataset {111/Inf}
# /quality_assessment/gt3r/lon_mean Dataset {111/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_0 Dataset {111/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_1 Dataset {111/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_2 Dataset {111/Inf}
# /quality_assessment/gt3r/signal_selection_source_fraction_3 Dataset {111/Inf}
# /quality_assessment/qa_granule_fail_reason Dataset {1}
# /quality_assessment/qa_granule_pass_fail Dataset {1}

# %%
import pyproj
from astropy.time import Time

def gps2dyr(time):
    """Converte GPS time to decimal years."""
    return Time(time, format='gps').decimalyear


def orbit_type(time, lat, tmax=1):
    """Separate tracks into ascending and descending.
    
    Defines tracks as segments with time breaks > tmax,
    and tests whether lat increases or decreases w/time.
    """
    tracks = np.zeros(lat.shape)  # generate track segment
    tracks[0:np.argmax(np.abs(lat))] = 1  # set values for segment
    is_asc = np.zeros(tracks.shape, dtype=bool)  # output index array

    # Loop trough individual secments
    for track in np.unique(tracks):
    
        i_track, = np.where(track == tracks)  # get all pts from seg
    
        if len(i_track) < 2: continue
    
        # Test if lat increases (asc) or decreases (des) w/time
        i_min = time[i_track].argmin()
        i_max = time[i_track].argmax()
        lat_diff = lat[i_track][i_max] - lat[i_track][i_min]
    
        # Determine track type
        if lat_diff > 0:  is_asc[i_track] = True
    
    return is_asc


def transform_coord(proj1, proj2, x, y):
    """Transform coordinates from proj1 to proj2 (EPSG num).

    Example EPSG projections:
        Geodetic (lon/lat): 4326
        Polar Stereo AnIS (x/y): 3031
        Polar Stereo GrIS (x/y): 3413
    """
    # Set full EPSG projection strings
    proj1 = pyproj.Proj("+init=EPSG:"+str(proj1))
    proj2 = pyproj.Proj("+init=EPSG:"+str(proj2))
    return pyproj.transform(proj1, proj2, x, y)  # convert

# %%
import h5py
import numpy as np

def read_atl06(fname, outdir='data', bbox=None):
    """Read one ATL06 file and output 6 reduced files. 
    
    Extract variables of interest and separate the ATL06 file 
    into each beam (ground track) and ascending/descending orbits.
    """

    # Each beam is a group
    group = ['/gt1l', '/gt1r', '/gt2l', '/gt2r', '/gt3l', '/gt3r']

    # Loop trough beams
    for k, g in enumerate(group):
    
        #-----------------------------------#
        # 1) Read in data for a single beam #
        #-----------------------------------#
        
        data = {}
    
        try:
            # Load vars into memory (include as many as you want)
            with h5py.File(fname, 'r') as fi:
                
                data['lat'] = fi[g+'/land_ice_segments/latitude'][:]
                data['lon'] = fi[g+'/land_ice_segments/longitude'][:]
                data['h_li'] = fi[g+'/land_ice_segments/h_li'][:]
                data['s_li'] = fi[g+'/land_ice_segments/h_li_sigma'][:]
                data['t_dt'] = fi[g+'/land_ice_segments/delta_time'][:]
                data['q_flag'] = fi[g+'/land_ice_segments/atl06_quality_summary'][:]
                data['s_fg'] = fi[g+'/land_ice_segments/fit_statistics/signal_selection_source'][:]
                data['snr'] = fi[g+'/land_ice_segments/fit_statistics/snr_significance'][:]
                data['h_rb'] = fi[g+'/land_ice_segments/fit_statistics/h_robust_sprd'][:]
                data['dac'] = fi[g+'/land_ice_segments/geophysical/dac'][:]
                data['f_sn'] = fi[g+'/land_ice_segments/geophysical/bsnow_conf'][:]
                data['dh_fit_dx'] = fi[g+'/land_ice_segments/fit_statistics/dh_fit_dx'][:]
                data['tide_earth'] = fi[g+'/land_ice_segments/geophysical/tide_earth'][:]
                data['tide_load'] = fi[g+'/land_ice_segments/geophysical/tide_load'][:]
                data['tide_ocean'] = fi[g+'/land_ice_segments/geophysical/tide_ocean'][:]
                data['tide_pole'] = fi[g+'/land_ice_segments/geophysical/tide_pole'][:]
                
                rgt = fi['/orbit_info/rgt'][:]                           # single value
                t_ref = fi['/ancillary_data/atlas_sdp_gps_epoch'][:]     # single value
                beam_type = fi[g].attrs["atlas_beam_type"].decode()      # strong/weak (str)
                spot_number = fi[g].attrs["atlas_spot_number"].decode()  # number (str)
                
        except:
            print('skeeping group:', g)
            print('in file:', fname)
            continue
            
        #---------------------------------------------#
        # 2) Filter data according region and quality #
        #---------------------------------------------#
        
        # Select a region of interest
        if bbox:
            lonmin, lonmax, latmin, latmax = bbox
            bbox_mask = (data['lon'] >= lonmin) & (data['lon'] <= lonmax) & \
                        (data['lat'] >= latmin) & (data['lat'] <= latmax)
        else:
            bbox_mask = np.ones_like(data['lat'], dtype=bool)  # get all
            
        # Only keep good data (quality flag + threshold + bbox)
        mask = (data['q_flag'] == 0) & (np.abs(data['h_li']) < 10e3) & (bbox_mask == 1)
        
        # If no data left, skeep
        if not any(mask): continue
        
        # Update data variables
        for k, v in data.items(): data[k] = v[mask]
            
        #----------------------------------------------------#
        # 3) Convert time, separate tracks, reproject coords #
        #----------------------------------------------------#
        
        # Time in GPS seconds (secs sinde Jan 5, 1980)
        t_gps = t_ref + data['t_dt']

        # Time in decimal years
        t_year = gps2dyr(t_gps)

        # Determine orbit type
        is_asc = orbit_type(t_year, data['lat'])
        
        # Geodetic lon/lat -> Polar Stereo x/y
        x, y = transform_coord(4326, 32607, data['lon'], data['lat'])
      
        data['x'] = x
        data['y'] = y
        data['t_gps'] = t_gps
        data['t_year'] = t_year
        data['is_asc'] = is_asc
        
        #-----------------------#
        # 4) Save selected data #
        #-----------------------#
        
        # Define output dir and file
        outdir = Path(outdir)    
        fname = Path(fname)
        outdir.mkdir(exist_ok=True)
        outfile = outdir / fname.name.replace('.h5', '_' + g[1:] + '.h5')
        
        # Save variables
        with h5py.File(outfile, 'w') as fo:
            for k, v in data.items(): fo[k] = v
            print('out ->', outfile)

# %%
# !python system-status.py
# Out:
# python: can't open file 'system-status.py': [Errno 2] No such file or directory

# %%
outdir = Path.home()/'crossovers/contributors/jun/data'

njobs = 8

bbox = None  #[-1124782, 81623, -919821, -96334]  # Kamb bounding box

outdir.mkdir(exist_ok=True)


if njobs == 1:
    print('running in serial ...')
    [read_atl06(f, outdir, bbox) for f in files]

else:
    print('running in parallel (%d jobs) ...' % njobs)
    from joblib import Parallel, delayed
    Parallel(n_jobs=njobs, verbose=5)(delayed(read_atl06)(f, outdir, bbox) for f in files)
# Out:
# running in parallel (8 jobs) ...
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done   2 out of   2 | elapsed:    1.3s finished

# %%
#outfiles = !ls {outdir}/*.h5
outfiles = list(outdir.glob('*.h5'))

for f in outfiles[:10]: print(f)
print('Total number of files:', len(outfiles))
# Out:
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20191119173713_08220505_003_01_gt2r.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20191119173713_08220505_003_01_gt3l.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20190814163946_07270405_003_01_gt2l.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20190814163946_07270405_003_01_gt2r.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20190814163946_07270405_003_01_gt1l.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20190814163946_07270405_003_01_gt3l.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20191119173713_08220505_003_01_gt3r.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20191119173713_08220505_003_01_gt1l.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20191119173713_08220505_003_01_gt1r.h5
# /home/junsaito/crossovers/contributors/jun/data/ATL06_20190814163946_07270405_003_01_gt1r.h5
# Total number of files: 12

# %%
# !h5ls -r {outfiles[0]}
# Out:
# /                        Group
# /dac                     Dataset {14653}
# /dh_fit_dx               Dataset {14653}
# /f_sn                    Dataset {14653}
# /h_li                    Dataset {14653}
# /h_rb                    Dataset {14653}
# /is_asc                  Dataset {14653}
# /lat                     Dataset {14653}
# /lon                     Dataset {14653}
# /q_flag                  Dataset {14653}
# /s_fg                    Dataset {14653}
# /s_li                    Dataset {14653}
# /snr                     Dataset {14653}
# /t_dt                    Dataset {14653}
# /t_gps                   Dataset {14653}
# /t_year                  Dataset {14653}
# /tide_earth              Dataset {14653}
# /tide_load               Dataset {14653}
# /tide_ocean              Dataset {14653}
# /tide_pole               Dataset {14653}
# /x                       Dataset {14653}
# /y                       Dataset {14653}

# %% [markdown]
# Select the data from a wide vriety of parameters.

# %%
import h5py
import numpy as np
import dask.dataframe as dd

import warnings
warnings.filterwarnings("ignore")


def read_h5(fname, vnames=[]):
    """Read a list of vars [v1, v2, ..] -> 2D."""
    with h5py.File(fname, 'r') as f:
        return np.column_stack([f[v][()] for v in vnames])

    
# # Get list of files to plot
files = list(outdir.glob('*.h5'))

# # Variables we want to plot
# #vnames = ['lon', 'lat', 'h_elv']
vnames = ['x', 'y', 'h_li','t_year']

# # List with one dataframe per file
dfs = [dd.from_array(read_h5(f, vnames), columns=vnames) for f in files]

# # Single parallel dataframe (larger than memory)
df = dd.concat(dfs)

print('Number of files:', len(files))
print('Number of points:', len(df))
print(df.head())
# Out:
# Number of files: 12
# Number of points: 471652
#                x             y      h_li      t_year
# 0  792613.634785  7.736502e+06 -7.337063  2019.88421
# 1  792613.643373  7.736482e+06 -7.336350  2019.88421
# 2  792613.619221  7.736462e+06 -7.338637  2019.88421
# 3  792613.546766  7.736442e+06 -7.343779  2019.88421
# 4  792613.449724  7.736422e+06 -7.330668  2019.88421

# %% [markdown]
# Save it as csv

# %%
df.to_csv(str(outdir)+'/points-*.csv')  # -> N csv files
# Out:
# ['/home/junsaito/crossovers/contributors/jun/data/points-00.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-01.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-02.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-03.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-04.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-05.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-06.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-07.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-08.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-09.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-10.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-11.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-12.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-13.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-14.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-15.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-16.csv',
#  '/home/junsaito/crossovers/contributors/jun/data/points-17.csv']

# %% [markdown]
# This code doesn't work suddenly. I don't know why. It is not important, though.

# %%
#%matplotlib widget
import datashader as ds
import datashader.transfer_functions as tf
from matplotlib.cm import terrain as cmap

df = dd.read_csv(str(outdir)+'/*.csv')
pts = ds.Canvas(plot_width=800, plot_height=800)
#agg = pts.points(df, 'lon', 'lat', ds.mean('h_elv'))
agg = pts.points(df, 'x', 'y', ds.mean('h_li'))
img = tf.shade(agg, cmap=cmap, how='linear')
img
# Out:
# <xarray.Image (y: 800, x: 800)>
# array([[  10040115, 4289282859,   10040115, ...,   10040115,   10040115,
#           10040115],
#        [  10040115,   10040115,   10040115, ...,   10040115,   10040115,
#           10040115],
#        [  10040115,   10040115,   10040115, ...,   10040115,   10040115,
#           10040115],
#        ...,
#        [  10040115,   10040115,   10040115, ...,   10040115,   10040115,
#           10040115],
#        [  10040115,   10040115,   10040115, ...,   10040115,   10040115,
#           10040115],
#        [  10040115,   10040115,   10040115, ...,   10040115,   10040115,
#           10040115]], dtype=uint32)
# Coordinates:
#   * x        (x) float64 7.774e+05 7.81e+05 7.845e+05 ... 3.615e+06 3.618e+06
#   * y        (y) float64 6.614e+06 6.618e+06 6.623e+06 ... 1.015e+07 1.016e+07

# %% [markdown]
# Make grid data from AarcticDEM. It is needed to extract value by Icesat2 data

# %%
# print out metadata information
#%matplotlib widget
import datashader as ds
import datashader.transfer_functions as tf
from matplotlib.cm import terrain as cmap
import rasterio as rio
from affine import Affine
from pyproj import Proj, transform as transform
file_in ='/home/junsaito/crossovers/contributors/jun/dem100m.tif'
src = rio.open(file_in)
for k in src.meta:
  print(k,src.meta[k])

# Retrieve the affine transformation
if isinstance(src.transform, Affine):
     transform = src.transform
else:
     transform = src.affine

N = src.width
M = src.height
dx = transform.a
dy = transform.e
minx = transform.c
maxy = transform.f

# Read the image data, flip upside down if necessary
data_in = src.read(1)
if dy < 0:
  dy = -dy
  data_in = np.flip(data_in, 0)

print('Data minimum, maximum( = ', np.amin(data_in), np.amax(data_in))
# Out:
# driver GTiff
# dtype float32
# nodata -9999.0
# width 546
# height 546
# count 1
# crs EPSG:32607
# transform | 95.79, 0.00, 650017.17|
# | 0.00,-95.79, 6579617.67|
# | 0.00, 0.00, 1.00|
# Data minimum, maximum( =  nan nan

# %%
# Generate X and Y grid locations
xdata = minx + dx/2 + dx*np.arange(N)
ydata = maxy - dy/2 - dy*np.arange(M-1,-1,-1)

# %% [markdown]
# Multiple csv files merge into a csv file

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import glob
appended_data = []
for infile in glob.glob('/home/junsaito/crossovers/contributors/jun/data/*.csv', recursive=True):
    data = pd.read_csv(infile)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
appended_data = pd.concat(appended_data)
# write DataFrame to an excel sheet 
appended_data.to_csv('/home/junsaito/crossovers/contributors/jun/appended.csv')

# %%
glas_fn = '/home/junsaito/crossovers/contributors/jun/appended.csv'
glas_df = pd.read_csv(glas_fn)

glas_gdf = gpd.GeoDataFrame(glas_df, geometry=gpd.points_from_xy(glas_df['x'],\
                                                   glas_df['y']), crs='EPSG:32607')

# %% [markdown]
# Check where icesat2 trak go onto ArcticDEM

# %%
import rasterio as rio
from rasterio import plot
from affine import Affine
import matplotlib.pyplot as plt
file_in3 ='/home/junsaito/crossovers/contributors/jun/dem100m.tif'
src = rio.open(file_in3)
srtm_extent = rio.plot.plotting_extent(src)
srtm = src.read(1, masked=True)

fig, ax = plt.subplots()
ax.imshow(srtm, extent=srtm_extent)
x1=glas_df['x']
y1=glas_df['y']
ax.scatter(x1,y1,marker='s',s=1,facecolors='none',edgecolors='k')
cs=ax.imshow(srtm, extent=srtm_extent,cmap=plt.get_cmap('Spectral'), interpolation='nearest',
               vmin=-200, vmax=4700)
cs=ax.imshow(srtm, extent=srtm_extent)
cs=fig.colorbar(cs,ax=ax,shrink=0.9)

# %% [markdown]
# Compare Icesat2 data with ArcticDEM

# %%
ex_ele=[]
for i in range(len(x1)):
    idy = (np.abs(ydata-y1[i])).argmin()
    idx=(np.abs(xdata-x1[i])).argmin()
    ele=data_in[idy,idx]
    ex_ele.append(ele)
z=glas_df['h_li']   
dif=z-ex_ele
df2 = pd.DataFrame({'Z': z[:],'Z1' : ex_ele[:],'Z_Z1':dif[:]})
df_concat = pd.concat([df2,glas_df], axis=1, sort=False)
print(df_concat)
# Out:
#                  Z      Z1          Z_Z1  Unnamed: 0  Unnamed: 0.1  \
# 0       462.726746 -9999.0  10461.726746           0             0
# 1       465.484741 -9999.0  10464.484741           1             1
# 2       473.329529 -9999.0  10472.329529           2             2
# 3       483.284058 -9999.0  10482.284058           3             3
# 4       485.208221 -9999.0  10484.208221           4             4
# ...            ...     ...           ...         ...           ...
# 471647   27.947832 -9999.0  10026.947832       11240         11240
# 471648   27.557455 -9999.0  10026.557455       11241         11241
# 471649   27.774162 -9999.0  10026.774162       11242         11242
# 471650   27.848652 -9999.0  10026.848652       11243         11243
# 471651  203.806091 -9999.0  10202.806091       11244         11244
#
#                    x             y        h_li       t_year  \
# 0       3.099316e+06  1.002398e+07  462.726746  2019.618348
# 1       3.099338e+06  1.002398e+07  465.484741  2019.618348
# 2       3.099381e+06  1.002398e+07  473.329529  2019.618348
# 3       3.099446e+06  1.002397e+07  483.284058  2019.618348
# 4       3.099467e+06  1.002397e+07  485.208221  2019.618348
# ...              ...           ...         ...          ...
# 471647  3.592525e+06  9.973300e+06   27.947832  2019.618350
# 471648  3.592547e+06  9.973297e+06   27.557455  2019.618350
# 471649  3.595373e+06  9.972971e+06   27.774162  2019.618350
# 471650  3.595395e+06  9.972968e+06   27.848652  2019.618350
# 471651  3.605455e+06  9.971795e+06  203.806091  2019.618350
#
#                                 geometry
# 0       POINT (3099316.158 10023981.823)
# 1       POINT (3099337.739 10023979.735)
# 2       POINT (3099380.902 10023975.559)
# 3       POINT (3099445.621 10023969.076)
# 4       POINT (3099467.187 10023966.847)
# ...                                  ...
# 471647   POINT (3592524.655 9973300.099)
# 471648   POINT (3592546.892 9973297.481)
# 471649   POINT (3595372.656 9972971.063)
# 471650   POINT (3595394.898 9972968.464)
# 471651   POINT (3605455.224 9971794.891)
#
# [471652 rows x 10 columns]

# %% [markdown]
# Finally, Plot on the map

# %%
#import matplotlib.pyplot as plt
#fig, ax = plt.subplots()
#fig = plt.figure()
ax = df_concat.plot(x='x', y='y', kind='scatter', c='Z_Z1', s=1, cmap='RdBu', vmin=-50, vmax=50,zorder=5)
#ax.set_title('Elevation change',size=20)
#ax.set_label('Elevation change (m)',size=15)


#file_in2 ='/home/jovyan/crossovers/Jun/LC08_L1TP_060019_20180703_20180717_01_T1_B8.TIF'
file_in2 ='/home/junsaito/crossovers/contributors/jun/dem100m.tif'
src1 = rio.open(file_in2)
srtm_extent1 = rio.plot.plotting_extent(src1)
srtm1 = src.read(1, masked=True)
ax.imshow(srtm1, extent=srtm_extent1)

# %%
f, ax = plt.subplots()
df_concat['Z_Z1'][df_concat['Z_Z1']>=50]=np.nan
df_concat['Z_Z1'][df_concat['Z_Z1']<=-50]=np.nan
df_concat.hist('Z_Z1', ax=ax, bins=100, range=(-50,50));
ax.axvline(0, color='k')
ax.axvline(df_concat['Z_Z1'].median(), color='r');
print(df_concat['Z_Z1'].median())
# Out:
# nan

# %%
ax = df_concat.plot('Z', 'Z_Z1', kind='scatter', s=1)
#Add a horizontal line at 0
ax.axhline(0, color='k', lw=0.5);

# %% [markdown]
# It would be helpful if we clip data with Polygon data in order to distingish between Ice and Ice free area.
